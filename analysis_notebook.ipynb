# %% [markdown]
# ## Data Gathering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Processing

# %% [markdown]
# Taking Dataset from : https://data.nal.usda.gov/dataset/data-field-scale-sensor-network-data-set-monitoring-and-modeling-spatial-and-temporal-variation-soil-moisture-dryland-agricultural-field

# %%
df = pd.read_csv('Raw Data/sensor_data/Daily/CAF003.txt',
                 sep='\t', index_col='Date')
df.index = pd.to_datetime(df.index, format="%m/%d/%Y")
df = df.loc['2016-01-01':'2016-01-30', :]
df.drop(columns={'Location'
                 }, inplace=True)
df.dropna().head()
# Out:
#             VW_30cm  VW_60cm  VW_90cm  VW_120cm  VW_150cm  T_30cm  T_60cm  \
# Date
# 2016-01-01    0.283    0.248    0.321     0.228     0.254   3.338   5.092
# 2016-01-02    0.281    0.248    0.321     0.228     0.254   3.213   5.000
# 2016-01-03    0.280    0.247    0.320     0.228     0.254   3.075   4.942
# 2016-01-04    0.278    0.247    0.320     0.228     0.253   3.000   4.817
# 2016-01-05    0.278    0.246    0.320     0.228     0.253   2.942   4.800
#
#             T_90cm  T_120cm  T_150cm
# Date
# 2016-01-01   5.933    6.458    7.800
# 2016-01-02   5.900    6.400    7.704
# 2016-01-03   5.825    6.350    7.687
# 2016-01-04   5.775    6.300    7.600
# 2016-01-05   5.700    6.212    7.567

# %% [markdown]
# - VW_30cm: volumetric water readings at 30 cm depth (m^3/m^3)
# - VW_60cm: volumetric water readings at 60 cm depth (m^3/m^3)
# - VW_90cm: volumetric water readings at 90 cm depth (m^3/m^3)
# - VW_120cm: volumetric water readings at 120 cm depth (m^3/m^3)
# - VW_150cm: volumetric water readings at 150 cm depth (m^3/m^3)
# - T_30cm: temperature readings at 30 cm depth (C)
# - T_60cm: temperature readings at 60 cm depth (C)
# - T_90cm: temperature readings at 90 cm depth (C)
# - T_120cm: temperature readings at 120 cm depth (C)
# - T_150cm: temperature readings at 150 cm depth (C)

# %% [markdown]
# ## Analysing

# %%
fig, axes = plt.subplots(figsize=(20, 8))
sns.lineplot(x=[str(i)[:10] for i in df.index], y='VW_30cm', data=df, ax=axes,marker='o')
plt.xticks(rotation=60, size=10)
plt.grid(color='brown')
plt.yticks(size=20)
plt.ylabel("VW_30cm", size=20)
plt.title("volumetric water readings at 30 cm depth", size=20)
plt.show()

# %%
fig, axes = plt.subplots(figsize=(20, 8))
sns.lineplot(x=[str(i)[:10] for i in df.index], y='VW_60cm', data=df, ax=axes,marker='o')
plt.xticks(rotation=60, size=10)
plt.grid(color='brown')
plt.yticks(size=20)
plt.ylabel("VW_60cm", size=20)
plt.title("volumetric water readings at 60 cm depth", size=20)
plt.show()

# %%
fig, axes = plt.subplots(figsize=(20, 8))
sns.lineplot(x=[str(i)[:10] for i in df.index], y='VW_120cm', data=df, ax=axes,marker='o')
plt.xticks(rotation=60, size=10)
plt.grid(color='brown')
plt.yticks(size=20)
plt.ylabel("VW_120cm", size=20)
plt.title("volumetric water readings at 120 cm depth", size=20)
plt.show()

# %%
fig, axes = plt.subplots(figsize=(20, 8))
sns.lineplot(x=[str(i)[:10] for i in df.index], y='VW_150cm', data=df, ax=axes,marker='o')
plt.xticks(rotation=60, size=10)
plt.grid(color='brown')
plt.yticks(size=20)
plt.ylabel("VW_150cm", size=20)
plt.title("volumetric water readings at 150 cm depth", size=20)
plt.show()

# %%
fig, axes = plt.subplots(figsize=(20, 8))
sns.barplot(x=[str(i)[:10] for i in df.index], y='T_30cm', data=df, ax=axes)
plt.xticks(rotation=60, size=10)
plt.grid(color='brown', alpha=0.3)
plt.yticks(size=20)
plt.ylabel("T_30cm", size=20)
plt.title("temperature readings at 30 cm depth (C)", size=20)
plt.show()

# %%
df.corr().loc['VW_30cm':'VW_150cm',
              'T_30cm':].style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_896e4d5a_a4b3_11ea_a59c_02236c0f1d0drow0_col0 {
#             background-color:  #fee7db;
#             color:  #000000;
#         }    #T_896e4d5a_a4b3_11ea_a59c_02236c0f1d0drow0_col1 {
#             background-color:  #fca98c;
#             color:  #000000;
#         }    #T_896e4d5a_a4b3_11ea_a59c_02236c0f1d0drow0_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_896e4d5a_a4b3_11ea_a59c_02236c0f1d0drow0_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_896e4d5a_a4b3_11ea_a59c_02236c0f1d0drow0_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_896e4d5a_a4b3_11ea_a59c_02236c0f1d0drow1_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_896e4d5a_a4b3_11ea_a59c_02236c0f1d0drow1_col1 {
#             background-color:  #ffece3;
#             color:  #000000;
# ...

# %%
fig, axes = plt.subplots(figsize=(20, 8))
sns.regplot(x='VW_30cm', y='T_30cm', data=df, ax=axes, lowess=True, marker='o')
plt.title("Corr : {0}".format(
    round(df['T_30cm'].corr(df['VW_30cm']), 3)), size=20)
plt.xticks(size=15)
plt.xlabel("VW_30cm", size=15)
plt.yticks(size=15)
plt.ylabel("T_30cm", size=15)
plt.show()

# %%
fig, axes = plt.subplots(figsize=(20, 8))
sns.regplot(x='VW_60cm', y='T_60cm', data=df, ax=axes, lowess=True, marker='o')
plt.title("Corr : {0}".format(
    round(df['T_60cm'].corr(df['VW_60cm']), 3)), size=20)
plt.xticks(size=15)
plt.xlabel("VW_60cm", size=15)
plt.yticks(size=15)
plt.ylabel("T_60cm", size=15)
plt.show()

# %%
fig, axes = plt.subplots(figsize=(20, 8))
sns.regplot(x='VW_90cm', y='T_90cm', data=df, ax=axes, lowess=True, marker='o')
plt.title("Corr : {0}".format(
    round(df['T_90cm'].corr(df['VW_90cm']), 3)), size=20)
plt.xticks(size=15)
plt.xlabel("VW_90cm", size=15)
plt.yticks(size=15)
plt.ylabel("T_90cm", size=15)
plt.show()

# %% [markdown]
# ## Disease Detection

# %%
fig, axes = plt.subplots(figsize=(20, 8))
plt.grid(linestyle='-.', color='brown', alpha=0.5)
sns.lineplot(x=[str(i)[:10] for i in df.index], y='VW_30cm',
             data=df, ax=axes, marker='o', color='green')
plt.xticks(rotation=60, size=12.5)
plt.ylabel("VW_30cm", size=15, color='green')
plt.yticks(color='green')
sns.lineplot(x=[str(i)[:10] for i in df.index], y='T_30cm',
             data=df, ax=axes.twinx(), marker='o', color='red')
plt.yticks(color='red', size=15)
plt.ylabel("T_30cm", size=15, color='red')
plt.title("VW_30cm and T_30cm", size=20)
plt.show()

# %%
fig, axes = plt.subplots(figsize=(20, 8))
plt.grid(linestyle='-.', color='brown', alpha=0.5)
sns.lineplot(x=[str(i)[:10] for i in df.index], y='VW_60cm',
             data=df, ax=axes, marker='o', color='green')
plt.xticks(rotation=60, size=12.5)
plt.ylabel("VW_60cm", size=15, color='green')
plt.yticks(color='green')
sns.lineplot(x=[str(i)[:10] for i in df.index], y='T_60cm',
             data=df, ax=axes.twinx(), marker='o', color='red')
plt.yticks(color='red', size=15)
plt.ylabel("T_60cm", size=15, color='red')
plt.title("VW_60cm and T_60cm", size=20)
plt.show()

# %%
fig, axes = plt.subplots(figsize=(20, 8))
plt.grid(linestyle='-.', color='brown', alpha=0.5)
sns.lineplot(x=[str(i)[:10] for i in df.index], y='VW_90cm',
             data=df, ax=axes, marker='o', color='green')
plt.xticks(rotation=60, size=12.5)
plt.ylabel("VW_90cm", size=15, color='green')
plt.yticks(color='green')
sns.lineplot(x=[str(i)[:10] for i in df.index], y='T_90cm',
             data=df, ax=axes.twinx(), marker='o', color='red')
plt.yticks(color='red', size=15)
plt.ylabel("T_90cm", size=15, color='red')
plt.title("VW_90cm and T_90cm", size=20)
plt.show()

# %%
fig, axes = plt.subplots(figsize=(20, 8))
plt.grid(linestyle='-.', color='brown', alpha=0.5)
sns.lineplot(x=[str(i)[:10] for i in df.index], y='VW_120cm',
             data=df, ax=axes, marker='o', color='green')
plt.xticks(rotation=60, size=12.5)
plt.ylabel("VW_120cm", size=15, color='green')
plt.yticks(color='green')
sns.lineplot(x=[str(i)[:10] for i in df.index], y='T_120cm',
             data=df, ax=axes.twinx(), marker='o', color='red')
plt.yticks(color='red', size=15)
plt.ylabel("T_120cm", size=15, color='red')
plt.title("VW_120cm and T_120cm", size=20)
plt.show()

# %%
fig, axes = plt.subplots(figsize=(20, 8))
plt.grid(linestyle='-.', color='brown', alpha=0.5)
sns.lineplot(x=[str(i)[:10] for i in df.index], y='VW_150cm',
             data=df, ax=axes, marker='o', color='green')
plt.xticks(rotation=60, size=12.5)
plt.ylabel("VW_150cm", size=15, color='green')
plt.yticks(color='green')
sns.lineplot(x=[str(i)[:10] for i in df.index], y='T_150cm',
             data=df, ax=axes.twinx(), marker='o', color='red')
plt.yticks(color='red', size=15)
plt.ylabel("T_150cm", size=15, color='red')
plt.title("VW_150cm and T_150cm", size=20)
plt.show()

# %% [markdown]
# ## Output

# %%
output_1 = pd.read_excel('Output Folder/plant_disease.xlsx')

# %%
output_1
# Out:
#   Plant Name                    Disease Name  \
# 0     Tomato                     Late Blight
# 1     Carrot                  Black Root Rot
# 2   Cucumber  Fungal(Alternaria leaf blight)
# 3       Peas          Fungal(Powdery mildew)
# 4      Beans         Common blight(bacteria)
# 5     Potato                   potato blight
# 6     Ginger        Bacterial wilt(Bacteria)
#
#                                  Disease Description  \
# 0            Two fungal diseases are known as blight
# 1  This disease display a black or brown decayed ...
# 2  This disease apper leaf surface as small circu...
# 3  It is usally covers the upper part of the leav...
# 4  This disease appears initial water soaked sapo...
# 5  This disease appears small, light to dark gree...
# 6  It appears water soaked patches on collar regi...
#
#                                               Remedy
# 0  Remove affected leaves and adjust care as nece...
# 1  Remove all infected plant material, Avoid reus...
# ...

# %%
output_2 = pd.read_excel('Output Folder/plant_maintain.xlsx')
output_2.head()
# Out:
#   Plant Name                                   Fertilizer  \
# 0     Tomato                                     Nitrogen
# 1        NaN                                  Phosphorous
# 2        NaN                                    Potassium
# 3     Carrot  Little nitrogen more potassium and phospate
# 4   Cucumber                                      Nitogen
#
#                                                Usage
# 0                   For continuous growth of foliage
# 1  For root and fruit development, and it also he...
# 2  For continuos growth,aids in photosynthesis an...
# 3  They are weight loss and lower cholesterol lev...
# 4               It will help the plant foliage grow.
